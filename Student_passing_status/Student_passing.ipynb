# %% [markdown]
# 1. Reverse a string word-by-word. e.g. "how are you" ->"you are how"

# %%
String_=input("Enter a string")
print(f"your string is: {String_}")
print(f"reversed string: {' '.join(String_.split()[::-1])}")
# Out:
# your string is: how is it
# reversed string: it is how

# %% [markdown]
# 2. Considering student dataset csv in following link,
# create another column that represent passing status of a student in maths. [>33% pass and <33% failed]
# link: https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?select=StudentsPerformance.csv

# %%
import pandas as pd
df=pd.read_csv("D:\Python\Codes\Celebal\Assignments\Student_passing_status\StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['student_status']=df['math score'].apply(lambda x:'Pass' if x >= 33 else 'Fail')
df[df['student_status']=='Fail']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 76     male        group E            some high school      standard
# 91     male        group C                 high school  free/reduced
# 145  female        group C                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 363  female        group D            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 528  female        group D           bachelor's degree  free/reduced
# 555  female        group C                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 601  female        group C                 high school      standard
# ...
